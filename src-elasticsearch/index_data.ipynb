# %%
'''
__author__: Jiaming Shen
__description__: Parse and index bioconcepts2pubtator_offsets.txt
'''
import time
import re
import sys 
import os
from collections import defaultdict
from elasticsearch import Elasticsearch
from elasticsearch_dsl import Search, Q

# %%
inputFilePath = "./indexer2/bioconcepts2pubtator_offsets.sample"
logFilePath = "./log.txt"
statFilePath = "./stats.txt"
dateFilePath = "./indexer2/pmid2date.txt"
INDEX_NAME = "pubmed_1211"
TYPE_NAME = "pubmed_entity"

# %%
es = Elasticsearch()

# %%
pmid2date = defaultdict(int)
start = time.time()
with open(dateFilePath, "r") as fin:
    for line in fin:
        line = line.strip()
        if line:
            tmp = line.split("\t")
            if len(tmp) == 2:
                pmid = tmp[0]
                try:
                    date = int(tmp[1])
                except:
                    date = 0
            pmid2date[pmid] = date
end = time.time()
print("Finish loading pmid2date file, using time %s (secondes)" % (end-start))
# Out:
# Finish loading pmid2date file, using time 0.23018693924 (secondes)

# %%
with open(inputFilePath, "r") as fin, open(logFilePath, "w") as fout:
    start = time.time()
    cnt = 0 # number of document processed
    bulk_size = 500 # number of document processed in each bulk index
    bulk_data = [] # data in bulk index

    ## saving the sum of all eight lengths for later model usage
    title_length_sum = 0
    abstract_length_sum = 0
    chemical_length_sum = 0
    disease_length_sum = 0
    gene_length_sum = 0
    mutation_length_sum = 0
    species_length_sum = 0
    total_length_sum = 0
    
    
    title = ""
    abstract = ""
    pmid = ""
    date = 0
    entities = defaultdict(list) # In the order of CDGMS == Chemical, Disease, Gene, Mutation, Species
    for line in fin:
        line = line.strip()
        if not line: # a document end
            ## Construct a data_dict for later indexing
            data_dict = {}
            total_length = 0
            data_dict["pmid"] = pmid
            data_dict["date"] = pmid2date[pmid]
            data_dict["title"] = title
            data_dict["title_length"] = len(title.split())
            total_length += data_dict["title_length"]
            data_dict["abstract"] = abstract
            data_dict["abstract_length"] = len(abstract.split())
            total_length += data_dict["abstract_length"]

            for entity_type in ["chemical", "disease", "gene", "mutation", "species"]:
                tmp = entities[entity_type]
                entity_field = " ".join(tmp) # construct a text field with all entity mentions joined by space
                entity_field_length = len(tmp)
                total_length += entity_field_length # accumulate each fields for later use
                data_dict[entity_type] = entity_field
                data_dict[entity_type + "_length"] = entity_field_length
            data_dict["total_length"] = total_length
            
            ## Update the length stats of each field
            title_length_sum += data_dict["title_length"]
            abstract_length_sum += data_dict["abstract_length"]
            chemical_length_sum += data_dict["chemical_length"]
            disease_length_sum += data_dict["disease_length"]
            gene_length_sum += data_dict["gene_length"]
            mutation_length_sum += data_dict["mutation_length"]
            species_length_sum += data_dict["species_length"]
            total_length_sum += data_dict["total_length"]
            
            ## Put current data into the bulk
            op_dict = {
                "index": {
                    "_index": INDEX_NAME,
                    "_type": TYPE_NAME,
                    "_id": data_dict["pmid"]
                }
            }
            
            bulk_data.append(op_dict)
            bulk_data.append(data_dict)
                        
            ## Re-initialize for next document
            title = ""
            abstract = ""
            pmid = ""
            entities = defaultdict(list)
            cnt += 1
            
            ## Start Bulk indexing
            if cnt % bulk_size == 0 and cnt != 0:
                tmp = time.time()
                es.bulk(index=INDEX_NAME, body=bulk_data, request_timeout = 180)
                fout.write("bulk indexing... %s, escaped time %s (seconds) \n" % ( cnt, tmp - start ) )
                print("bulk indexing... %s, escaped time %s (seconds) \n" % ( cnt, tmp - start ) )
                bulk_data = []
                
        else: # in the middle of a document
            if re.match(r"^\d+\|t\|", line): # title
                pmid = line.split("|t|")[0]
                title = line.split("|t|")[1]
            elif re.match(r"^\d+\|a\|", line): # abstract
                abstract = line.split("|a|")[1]
            else:
                tmp = line.split("\t")
                entity_mention = "_".join(tmp[3].split()) # use "_" to connect multiwords entity
                entity_type = tmp[4].lower()
                entities[entity_type].append(entity_mention)

    ## indexing those left papers
    tmp = time.time()
    es.bulk(index=INDEX_NAME, body=bulk_data, request_timeout = 180)
    fout.write("bulk indexing... %s, escaped time %s (seconds) \n" % ( cnt, tmp - start ) )
    print("bulk indexing... %s, escaped time %s (seconds) \n" % ( cnt, tmp - start ) )
    bulk_data = []

    end = time.time()
    fout.write("Finish indexing. Total escaped time %s (seconds) \n" % (end - start) )
    print("Finish indexing. Total escaped time %s (seconds) \n" % (end - start) )

print("Start saving statistics \n ")
with open(statFilePath, "w") as fout:
    fout.write("NUM_PAPER = %s\n" % cnt)
    fout.write("TITLE_LENGTH_SUM = %s\n" % title_length_sum)
    fout.write("ABSTRACT_LENGTH_SUM = %s\n" % abstract_length_sum)
    fout.write("CHEMICAL_LENGTH_SUM = %s\n" % chemical_length_sum)
    fout.write("DISEASE_LENGTH_SUM = %s\n" % disease_length_sum)
    fout.write("GENE_LENGTH_SUM = %s\n" % gene_length_sum)
    fout.write("MUTATION_LENGTH_SUM = %s\n" % mutation_length_sum)
    fout.write("SPECIES_LENGTH_SUM = %s\n" % species_length_sum)
    fout.write("TOTAL_LENGTH_SUM = %s\n" % total_length_sum)
# Out:
# bulk indexing... 500, escaped time 0.0392189025879 (seconds)
#
# bulk indexing... 1000, escaped time 0.227840900421 (seconds)
#
# bulk indexing... 1500, escaped time 0.506902933121 (seconds)
#
# bulk indexing... 2000, escaped time 0.735210895538 (seconds)
#
# bulk indexing... 2500, escaped time 1.01954078674 (seconds)
#
# bulk indexing... 3000, escaped time 1.18617582321 (seconds)
#
# bulk indexing... 3500, escaped time 1.36645483971 (seconds)
#
# bulk indexing... 4000, escaped time 1.54008078575 (seconds)
#
# bulk indexing... 4500, escaped time 1.72378182411 (seconds)
#
# bulk indexing... 5000, escaped time 1.91985297203 (seconds)
#
# bulk indexing... 5500, escaped time 2.09744787216 (seconds)
#
# bulk indexing... 6000, escaped time 2.27341389656 (seconds)
#
# bulk indexing... 6500, escaped time 2.47899580002 (seconds)
#
# bulk indexing... 7000, escaped time 2.63081479073 (seconds)
#
# bulk indexing... 7500, escaped time 2.79257678986 (seconds)
#
# bulk indexing... 8000, escaped time 2.970443964 (seconds)
#
# bulk indexing... 8500, escaped time 3.13672184944 (seconds)
#
# bulk indexing... 9000, escaped time 3.30790185928 (seconds)
#
# bulk indexing... 9500, escaped time 3.53123998642 (seconds)
#
# bulk indexing... 10000, escaped time 3.74639296532 (seconds)
#
# bulk indexing... 10500, escaped time 3.91931700706 (seconds)
#
# bulk indexing... 11000, escaped time 4.08055281639 (seconds)
#
# bulk indexing... 11500, escaped time 4.2292368412 (seconds)
#
# bulk indexing... 12000, escaped time 4.39309692383 (seconds)
#
# bulk indexing... 12500, escaped time 4.5561299324 (seconds)
#
# bulk indexing... 13000, escaped time 4.72461700439 (seconds)
#
# bulk indexing... 13500, escaped time 4.88682889938 (seconds)
#
# bulk indexing... 14000, escaped time 5.05879092216 (seconds)
#
# bulk indexing... 14500, escaped time 5.2191529274 (seconds)
#
# bulk indexing... 15000, escaped time 5.37863183022 (seconds)
#
# bulk indexing... 15500, escaped time 5.54302000999 (seconds)
#
# bulk indexing... 16000, escaped time 5.70932078362 (seconds)
#
# bulk indexing... 16500, escaped time 5.93735194206 (seconds)
#
# bulk indexing... 17000, escaped time 6.12820482254 (seconds)
#
# bulk indexing... 17500, escaped time 6.29860782623 (seconds)
#
# bulk indexing... 18000, escaped time 6.46964597702 (seconds)
#
# bulk indexing... 18500, escaped time 6.64399600029 (seconds)
#
# bulk indexing... 19000, escaped time 6.80485486984 (seconds)
#
# bulk indexing... 19500, escaped time 6.9756538868 (seconds)
#
# bulk indexing... 20000, escaped time 7.21453285217 (seconds)
#
# bulk indexing... 20500, escaped time 7.38145089149 (seconds)
#
# bulk indexing... 21000, escaped time 7.54079794884 (seconds)
#
# bulk indexing... 21500, escaped time 7.79336881638 (seconds)
#
# bulk indexing... 22000, escaped time 7.9429628849 (seconds)
#
# bulk indexing... 22500, escaped time 8.09327888489 (seconds)
#
# bulk indexing... 23000, escaped time 8.24386096001 (seconds)
#
# bulk indexing... 23500, escaped time 8.43037581444 (seconds)
#
# bulk indexing... 24000, escaped time 8.6541428566 (seconds)
#
# bulk indexing... 24500, escaped time 8.82204699516 (seconds)
#
# bulk indexing... 25000, escaped time 8.99182987213 (seconds)
#
# bulk indexing... 25500, escaped time 9.312240839 (seconds)
#
# bulk indexing... 26000, escaped time 9.59737896919 (seconds)
#
# bulk indexing... 26500, escaped time 9.79483890533 (seconds)
#
# bulk indexing... 27000, escaped time 9.94480991364 (seconds)
#
# bulk indexing... 27500, escaped time 10.1007909775 (seconds)
#
# bulk indexing... 28000, escaped time 10.3065998554 (seconds)
#
# bulk indexing... 28500, escaped time 10.4884059429 (seconds)
#
# bulk indexing... 29000, escaped time 10.7083649635 (seconds)
#
# bulk indexing... 29500, escaped time 10.9005730152 (seconds)
#
# bulk indexing... 30000, escaped time 11.0406479836 (seconds)
#
# bulk indexing... 30500, escaped time 11.1935319901 (seconds)
#
# bulk indexing... 31000, escaped time 11.3579769135 (seconds)
#
# bulk indexing... 31500, escaped time 11.5234758854 (seconds)
#
# bulk indexing... 32000, escaped time 11.6755838394 (seconds)
#
# bulk indexing... 32500, escaped time 11.8205318451 (seconds)
#
# bulk indexing... 33000, escaped time 11.980604887 (seconds)
#
# bulk indexing... 33500, escaped time 12.1323349476 (seconds)
#
# bulk indexing... 34000, escaped time 12.2852208614 (seconds)
#
# bulk indexing... 34500, escaped time 12.4500029087 (seconds)
#
# bulk indexing... 35000, escaped time 12.6024739742 (seconds)
#
# bulk indexing... 35500, escaped time 12.7545158863 (seconds)
#
# bulk indexing... 36000, escaped time 12.9754498005 (seconds)
#
# bulk indexing... 36500, escaped time 13.1289098263 (seconds)
#
# bulk indexing... 37000, escaped time 13.2808380127 (seconds)
#
# bulk indexing... 37500, escaped time 13.4290909767 (seconds)
#
# bulk indexing... 38000, escaped time 13.57376194 (seconds)
#
# bulk indexing... 38500, escaped time 13.7188057899 (seconds)
#
# bulk indexing... 39000, escaped time 13.8589508533 (seconds)
#
# bulk indexing... 39500, escaped time 14.0042769909 (seconds)
#
# bulk indexing... 40000, escaped time 14.1619138718 (seconds)
#
# bulk indexing... 40500, escaped time 14.3137059212 (seconds)
#
# bulk indexing... 41000, escaped time 14.4693288803 (seconds)
#
# bulk indexing... 41500, escaped time 14.6216108799 (seconds)
#
# bulk indexing... 42000, escaped time 14.7738490105 (seconds)
#
# bulk indexing... 42500, escaped time 14.9238789082 (seconds)
#
# bulk indexing... 43000, escaped time 15.0851378441 (seconds)
#
# bulk indexing... 43500, escaped time 15.2409207821 (seconds)
#
# bulk indexing... 44000, escaped time 15.4018797874 (seconds)
#
# bulk indexing... 44500, escaped time 15.5611479282 (seconds)
#
# bulk indexing... 45000, escaped time 15.7217738628 (seconds)
#
# bulk indexing... 45500, escaped time 15.9034268856 (seconds)
#
# bulk indexing... 46000, escaped time 16.048625946 (seconds)
#
# bulk indexing... 46500, escaped time 16.1991047859 (seconds)
#
# bulk indexing... 47000, escaped time 16.3428390026 (seconds)
#
# bulk indexing... 47500, escaped time 16.4795730114 (seconds)
#
# bulk indexing... 48000, escaped time 16.6110959053 (seconds)
#
# bulk indexing... 48500, escaped time 16.7605249882 (seconds)
#
# bulk indexing... 49000, escaped time 16.923997879 (seconds)
#
# bulk indexing... 49500, escaped time 17.0597789288 (seconds)
#
# bulk indexing... 50000, escaped time 17.2042520046 (seconds)
#
# bulk indexing... 50500, escaped time 17.3571629524 (seconds)
#
# bulk indexing... 51000, escaped time 17.5068368912 (seconds)
#
# bulk indexing... 51500, escaped time 17.6514167786 (seconds)
#
# bulk indexing... 52000, escaped time 17.7978827953 (seconds)
#
# bulk indexing... 52500, escaped time 17.9436509609 (seconds)
#
# bulk indexing... 53000, escaped time 18.089607954 (seconds)
#
# bulk indexing... 53500, escaped time 18.2353219986 (seconds)
#
# bulk indexing... 54000, escaped time 18.3792788982 (seconds)
#
# bulk indexing... 54500, escaped time 18.528605938 (seconds)
#
# bulk indexing... 55000, escaped time 18.710682869 (seconds)
#
# bulk indexing... 55500, escaped time 18.8579528332 (seconds)
#
# bulk indexing... 56000, escaped time 19.0125198364 (seconds)
#
# bulk indexing... 56500, escaped time 19.3442108631 (seconds)
#
# bulk indexing... 57000, escaped time 19.5899448395 (seconds)
#
# bulk indexing... 57500, escaped time 19.7362129688 (seconds)
#
# bulk indexing... 58000, escaped time 19.8762128353 (seconds)
#
# bulk indexing... 58500, escaped time 20.0310239792 (seconds)
#
# bulk indexing... 59000, escaped time 20.1759388447 (seconds)
#
# bulk indexing... 59380, escaped time 20.3245868683 (seconds)
#
# Finish indexing. Total escaped time 20.41157794 (seconds)
#
# Start saving statistics
